# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="bezserv.mysql.tools",
  user="bezserv_yourchikova",
  password="Vi@dB37_p2",
  database="bezserv_yourchikova"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM cells")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
    
    
# - SELECT одночасно з кількох таблиць разом з JOIN усіх видів
sql = "SELECT * FROM `cells` INNER JOIN `cell_functions` ON `cell_functions`.`id_cell_functions`=`cells`.`cell_function_id`;"
mycursor.execute(sql)
print("-----First query-------")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
    
sql = "SELECT * FROM `cells` LEFT JOIN `cell_functions` ON `cell_functions`.`id_cell_functions`=`cells`.`cell_function_id`;"
mycursor.execute(sql)
print("-----Second query-------")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
    
sql = "SELECT * FROM `cells` RIGHT JOIN `cell_functions` ON `cell_functions`.`id_cell_functions`=`cells`.`cell_function_id`;"
mycursor.execute(sql)
print("-----Third query-------")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
    
sql = "SELECT `organelles_id`, SUM(`size`), AVG(`size`) FROM `cells` GROUP BY `cells`.`organelles_id` HAVING `organelles_id` > 1;"
mycursor.execute(sql)
print("-----Group by query-------")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)

#- Вкладені запити SELECT з використанням виразів ANY та ALL
sql = "SELECT * FROM `cells` WHERE `cells`.`cell_function_id` = ANY (SELECT `id_cell_functions` FROM `cell_functions` WHERE `cell_functions`.`id_cell_functions` < 3);"
mycursor.execute(sql)
print("-----Any by query-------")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
    
sql = "SELECT * FROM `cells` WHERE `cells`.`cell_function_id` <> ALL (SELECT `id_cell_functions` FROM `cell_functions` WHERE `cell_functions`.`id_cell_functions` < 3);"
mycursor.execute(sql)
print("-----All by query-------")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (1, 'Клітина 1', 1, 0, 1, 3)
# (5, 'Клітина 3', 3, 3, 3, 1)
# (4, 'Клітина 4', 4, 0, 4, 5)
# -----First query-------
# (1, 'Клітина 1', 1, 0, 1, 3, 1, 'Функція 1')
# (5, 'Клітина 3', 3, 3, 3, 1, 3, 'Функція 2')
# (4, 'Клітина 4', 4, 0, 4, 5, 4, 'Функція 4')
# -----Second query-------
# (1, 'Клітина 1', 1, 0, 1, 3, 1, 'Функція 1')
# (5, 'Клітина 3', 3, 3, 3, 1, 3, 'Функція 2')
# (4, 'Клітина 4', 4, 0, 4, 5, 4, 'Функція 4')
# -----Third query-------
# (1, 'Клітина 1', 1, 0, 1, 3, 1, 'Функція 1')
# (5, 'Клітина 3', 3, 3, 3, 1, 3, 'Функція 2')
# (4, 'Клітина 4', 4, 0, 4, 5, 4, 'Функція 4')
# (None, None, None, None, None, None, 2, 'Функція 2')
# -----Group by query-------
# (3, Decimal('1'), Decimal('1.0000'))
# -----Any by query-------
# (1, 'Клітина 1', 1, 0, 1, 3)
# -----All by query-------
# (5, 'Клітина 3', 3, 3, 3, 1)
# (4, 'Клітина 4', 4, 0, 4, 5)
