# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

sns.set()
matplotlib.rcParams['figure.figsize'] = (20.0, 8.0)

# %%
import pandas as pd
df = pd.read_csv('time_task2.txt', sep=";")
df = df.iloc[:, :-1]
df.head()
# Out:
#      k  Time With Array  Memory With Array  Time With Variable  \
# 0  100          1273791              16384              369641
# 1  200            38873              32768              105977
# 2  300            53196              57344              164545
# 3  400            70851              81920              218018
# 4  500            90083             114688              275700
#
#    Memory With Variable
# 0                 32768
# 1                 81920
# 2                155648
# 3                237568
# 4                327680

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
time_col = [col for col in df if col.startswith('Time')]
data.plot('k', time_col, ax = ax1)
memory_col = [col for col in df if col.startswith('Memory')]
data.plot('k', memory_col, ax = ax2)
